# %% [markdown]
# # Seaborn visualization library

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# Seaborn helps you explore and understand your data its plotting functions operate on dataframes and arrays containing whole datasets and internally perform
# the necessary semantic mapping and statistical aggregation to produce informative plots.

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns

# %%
x = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thrusday']
y = [4,5,6,7,8]

# %%
sns.stripplot(x,y)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
df = pd.read_csv('emptest.csv')
df
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.violinplot(x='Salary',data=df)
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.violinplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.get_dataset_names()    # they all are dataset inside sns
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.stripplot?

# %%
help(sns.stripplot)

# %%
sns.stripplot(x='sepal_length',y='species',data=iris)    # easily understand below code
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.stripplot(x='species',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species',y='petal_length',data=iris)   # setosa versicolor, virginica they are flower
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.swarmplot(x='species',y='petal_length',data=iris)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.countplot(iris['species'])   # below line ko hatne ke liye hume warning ko import krna hoga below code me iska use kiya hai
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.countplot(iris['species'])
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
iris['species'].value_counts()  # 50 rows for setosa, 50 rows for versicolor.......
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
tipsds = sns.load_dataset('tips')
tipsds
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='total_bill',data=tipsds)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.violinplot(x='tip',data=tipsds)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.countplot(tipsds['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(tipsds['time'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
tipsds['time'].value_counts()  # 176 people are arived at dinner and 68 are arived at lunch
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.regplot(x='total_bill',y='tip',data=tipsds)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tipsds)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Load data
titanicds = sns.load_dataset('titanic')
print(titanicds)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
import seaborn
import seaborn as sns
sns.catplot?

# %%
# Set up a category plot
g = sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='bar')
# Show plot
# plt.show()

# %%
# Set up a category plot
g = sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='violin')
# Show plot
# plt.show()

# %%
# Load the data
tips = sns.load_dataset('tips')
print(tips.head())
# Create violinplot
sns.violinplot(x='total_bill',data=tips)
# Show the plot
# plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot?

# %%
sns.histplot(data=tips,x='total_bill',bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot?

# %%
sns.distplot(tips['tip'],bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"],bins=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
import seaborn as sns
# sns distplot?

# %%
sns.distplot(tips["total_bill"],bins=50,kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot?

# %%
sns.kdeplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Composite views onto multivariate datasets

# %%
sns.jointplot(data=tips,x="total_bill",y='tip')

# %%
# sns.rugplot?
sns.rugplot(data=tips,x='tip')
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips,x="total_bill",y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# sns.boxplot?

# %%
sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
