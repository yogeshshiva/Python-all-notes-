# %% [markdown]
# # Matplotlib

# %%
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = np.array([3,15,20,28,35,40])
temp
# Out:
# array([ 3, 15, 20, 28, 35, 40])

# %%
plt.plot(temp)

# %%
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
month = np.array(['Jan','Feb','March','April','May','June'])
month
# Out:
# array(['Jan', 'Feb', 'March', 'April', 'May', 'June'], dtype='<U5')

# %%
plt.plot(temp,month)
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.plot(month,temp)
plt.xlabel("Month")
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.plot(month,temp)
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,marker='o')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,marker='*')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,marker='+')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,color='g',marker='o')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,color='b',marker='*')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,'bo')   # b is blue color and o is point
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,'bo--')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
plt.plot(month,temp,'go--')
plt.xlabel("Month")
plt.ylabel('Temperature')
plt.title("Monthly Temperature")
plt.show()

# %%
x = ['Apple', 'Banana', 'Grapes']
y = [100, 150, 200]

plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x = ['Apple', 'Banana', 'Grapes']
y = [100, 150, 200]

plt.bar(x,y)
plt.xlabel("Fruits")
plt.ylabel("Number of fruits")
plt.show()

# %%
x = ['Apple', 'Banana', 'Grapes']
y = [100, 150, 200]

plt.bar(x,y,color='g')
plt.xlabel("Fruits")
plt.ylabel("Number of fruits")
plt.show()

# %%
x = ['Apple', 'Banana', 'Grapes']
y = [100, 150, 200]

plt.bar(x,y,color='g',align='center')
plt.xlabel("Fruits")
plt.ylabel("Number of fruits")
plt.show()

# %%
x = ['Apple', 'Banana', 'Grapes']
y = [100, 150, 200]

plt.bar(x,y,color='g',align='edge')
plt.xlabel("Fruits")
plt.ylabel("Number of fruits")
plt.show()

# %% [markdown]
# Histogram

# %% [markdown]
# A histogram takes in a series of data and divides the data into a number of bins. It then plots the frequency data points in each bin (i.e. the interval of points), it is useful in understanding the count of data ranges. When to use. We should use histogram when we need the count of the variable in a plot.

# %%
c = np.array([15,40,68,15,90,35,18,40,25,28,55,58,54,66,72,84])
plt.hist(c)
plt.show()

# %%
c = np.array([15,40,68,15,90,35,18,40,25,28,55,58,54,66,72,84])
plt.hist(c,bins=20)
plt.show()

# %%
c = np.array([15,40,68,15,90,35,18,40,25,28,55,58,54,66,72,84])    # 20 to 40 3no are their 40 to 60 5no are their
plt.hist(c,bins=[0,20,40,60,80,100])
plt.show()

# %%
x = np.array([10,20,30,40,60])

y = np.array([1,2,3,4,5])

plt.scatter(x,y)

# %%
x = np.array([14,10,55,20,52,23,30,40,56,60])

y = np.array([1,2,3,4,5,7,8,9,10,11])

plt.scatter(x,y)

# %%
x = np.array([14,10,55,20,52,23,30,40,56,60])

y = np.array([1,2,3,4,5,7,8,9,10,11])

plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
y = np.array([14,10,55,20,52,23,30,40,56,60])

x = np.array([1,2,3,4,5,7,8,9,10,11])

plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
g = np.array([3,6,44,12,67,45,55])
h = np.array([22,4,5,6,78,22,12])
plt.xlabel('g')
plt.ylabel('h')
plt.plot(g,h)
plt.show()

# %%
plt.plot(g,h,'--g')
plt.show()

# %%
g = np.array([3,6,44,12,67,45,55])
h = np.array([22,4,5,6,78,22,12])
plt.xlabel('g')
plt.ylabel('h')
plt.plot(g,h,color='red',marker='o')
plt.show()

# %%
g = np.array([3,6,44,12,67,45,55])
h = np.array([22,4,5,6,78,22,12])
plt.xlabel('g')
plt.ylabel('h')
plt.plot(g,h,'--r+')
plt.show()

# %%
x = [5,8,10,2,6,12]
y = [12,16,6,10,14,6]
plt.bar(x,y)
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.bar(x,y,color='g',align='center')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %% [raw]
# Create test file this below data and save student_marks.csv name
# ,Gender,DOB,Maths,Physics,Chemistry,English,Biology,Economics,History,Civics
# John,M,05-04-1988,55,45,56,87,21,52,89,65
# Suresh,M,04-05-1987,75,96,78,64,90,61,58,2
# Ramesh,M,25-05-1989,25,54,89,76,95,87,56,74
# Jessica,F,12-08-1990,78,96,86,63,54,89,75,45
# Jennifer,F,02-09-1989,58,96,78,46,96,77,83,53
# Annu,F,05-04-1988,45,87,52,89,55,89,87,52
# pooja,F,04-05-1987,55,64,61,58,75,58,64,61
# Ritesh,M,25-05-1989,54,76,87,56,25,56,76,87
# Farha,F,12-08-1990,55,63,89,75,78,75,63,89
# Mukesh,M,02-09-1989,96,46,77,83,58,83,46,77

# %%
import pandas as pd
df = pd.read_csv('student_marks.csv')
print(df)
df.columns
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
plt.hist(df['Maths'],bins=[0,20,40,60,80,100])
plt.title('Maths Histogram')
plt.show()

# %%
plt.hist(df['English'],bins=10)
plt.title('English')
plt.show()

# %%
# Boxplot
plt.boxplot(df['Maths'])    # boxplot show min and max marks
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ca25765a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ca256aa040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ca25765760>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ca256aa5e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ca256aa8b0>],
#  'means': []}

# %%
plt.violinplot(df['Maths'])   # avg marks of students are 50 to 60
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1ca260401c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1ca26040130>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1ca260408b0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1ca26040c70>}

# %%
plt.violinplot(df['Chemistry'])   # 80 to 90 avg marks here
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1ca2607f5b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1ca2607f520>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1ca2607fc70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1ca2608f070>}

# %%
x = np.array([3,6,44,12,67,45,55])
y = np.array([22,4,5,6,78,22,12])
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y)
plt.show()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
b = np.array([24,88,51,23,46,77,56,34,21,80,11,58,29,21,97])
plt.title('scatter plot')
plt.xlabel('a')
plt.ylabel('b')
plt.scatter(a,b)
plt.show()

# %%
x = df['Maths']
y = df['English']

# %%
plt.scatter(x,y)
plt.xlabel('Maths')
plt.ylabel('English')
plt.show()
